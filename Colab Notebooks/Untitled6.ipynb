# %%
# !ls
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_train = pd.read_csv('train.csv')
df_train.head(5)
# Out:
# data_description.txt  sample_data  test.csv  train.csv
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
len(df_train)
# Out:
# 1460

# %%
#맨 오른쪽의 정답과, 맨 왼쪽의 ID는 정답추론에 큰 의미가 없으니
#총 79개의 칼럼을 이용해 계산을 해야 함
len(df_train.columns)
# Out:
# 81

# %%
#칼럼 이름의 프린트
#칼럼의 타입이 오브젝트이냐 아니냐, 숫자냐 아니냐를 보고자 함
for f in df_train.columns:
  print(df_train.dtypes[f])
# Out:
# int64
# int64
# object
# float64
# int64
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# int64
# int64
# int64
# int64
# object
# object
# object
# object
# object
# float64
# object
# object
# object
# object
# object
# object
# object
# int64
# object
# int64
# int64
# int64
# object
# object
# object
# object
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# object
# int64
# object
# int64
# object
# object
# float64
# object
# int64
# int64
# object
# object
# object
# int64
# int64
# int64
# int64
# int64
# int64
# object
# object
# object
# int64
# int64
# int64
# object
# object
# int64

# %%
numeric = [f for f in df_train.columns if df_train.dtypes[f] != 'object'] #숫자형만
numeric
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
numeric.remove('Id')
numeric.remove('SalePrice')

categorical = [f for f in df_train.columns if df_train.dtypes[f] == 'object']
categorical
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
len(numeric)
# Out:
# 36

# %%
#누메릭은 36 + ID + Saleprice로
#카테고리컬은 43개로 총 81개의 칼럼 존재 확인
len(categorical)
# Out:
# 43

# %%
"""
레이블 확인코자 함. 
describe함수 통해, 여러 상위값, 중간값, 개수 등을 구해줌
"""

df_train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sns.distplot(df_train['SalePrice']); #분포도 보기
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#라벨과 feature간 상관관계 파악하기
#가격과 GarLivArea 간 상관관계 파악하기
var = 'GrLivArea'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis = 1)
data
# Out:
#       SalePrice  GrLivArea
# 0        208500       1710
# 1        181500       1262
# 2        223500       1786
# 3        140000       1717
# 4        250000       2198
# ...         ...        ...
# 1455     175000       1647
# 1456     210000       2073
# 1457     266500       2340
# 1458     142125       1078
# 1459     147500       1256
#
# [1460 rows x 2 columns]

# %%
#분포도 보기
#GrLivArea 칼럼과 SalePrice 칼럼 간의 분포도를 본다.
#이외에도 칼럼 명만 바꾸는 것으로 칼럼 간 분포도 보기가능
data.plot.scatter(x='GrLivArea', y='SalePrice', ylim=(0, 800000));

# %%
#overall quality가 높을수록 집값이 높다는 것을 확인 가능
var = 'OverallQual'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis = 1)
data.plot.scatter(x=var, y='SalePrice', ylim = (0, 800000));

# %%
df_train['Neighborhood']
# Out:
# 0       CollgCr
# 1       Veenker
# 2       CollgCr
# 3       Crawfor
# 4       NoRidge
#          ...
# 1455    Gilbert
# 1456     NWAmes
# 1457    Crawfor
# 1458      NAmes
# 1459    Edwards
# Name: Neighborhood, Length: 1460, dtype: object

# %%
var = 'Neighborhood'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis = 1)
data.plot.scatter(x=var, y='SalePrice', ylim = (0, 800000));

# %%
sns.boxplot(x=var, y='SalePrice', data = data)

# %%
#특정 두 feautre간의 corelation 파악
#텍스트인 건 칼럼을 기본적으로 제외시킴
#숫자인 것만 칼럼이 남아있게 되고,
#숫자인 것 끼리 corelaion 계산
df_train['GrLivArea'].corr(df_train['SalePrice'])
# Out:
# 0.7086244776126523

# %%
#또는 모든 피쳐간의 corelation 전부 계싼
cormat = df_train.corr()
cormat
# Out:
#                      Id  MSSubClass  LotFrontage  ...    MoSold    YrSold  SalePrice
# Id             1.000000    0.011156    -0.010601  ...  0.021172  0.000712  -0.021917
# MSSubClass     0.011156    1.000000    -0.386347  ... -0.013585 -0.021407  -0.084284
# LotFrontage   -0.010601   -0.386347     1.000000  ...  0.011200  0.007450   0.351799
# LotArea       -0.033226   -0.139781     0.426095  ...  0.001205 -0.014261   0.263843
# OverallQual   -0.028365    0.032628     0.251646  ...  0.070815 -0.027347   0.790982
# OverallCond    0.012609   -0.059316    -0.059213  ... -0.003511  0.043950  -0.077856
# YearBuilt     -0.012713    0.027850     0.123349  ...  0.012398 -0.013618   0.522897
# YearRemodAdd  -0.021998    0.040581     0.088866  ...  0.021490  0.035743   0.507101
# MasVnrArea    -0.050298    0.022936     0.193458  ... -0.005965 -0.008201   0.477493
# BsmtFinSF1    -0.005024   -0.069836     0.233633  ... -0.015727  0.014359   0.386420
# ...

# %%
#색깔 밝을수록 중요한 상관관계 지님
x, ax = plt.subplots(figsize = (12, 9))
sns.heatmap(cormat, vmax = .8, square = True);

# %%
#상관관계 높은 것 순으로 봐보자
cormat['SalePrice'] #판매가격과 다른것 간의 상관관계 표시

# 수치(numeric)로만 보고, 카테고리컬 한 것은 아직 보지 않았다.
#아래건 누메릭이다. 
cormat.sort_values(by=['SalePrice'])['SalePrice']
# Out:
# KitchenAbvGr    -0.135907
# EnclosedPorch   -0.128578
# MSSubClass      -0.084284
# OverallCond     -0.077856
# YrSold          -0.028923
# LowQualFinSF    -0.025606
# Id              -0.021917
# MiscVal         -0.021190
# BsmtHalfBath    -0.016844
# BsmtFinSF2      -0.011378
# 3SsnPorch        0.044584
# MoSold           0.046432
# PoolArea         0.092404
# ScreenPorch      0.111447
# BedroomAbvGr     0.168213
# BsmtUnfSF        0.214479
# BsmtFullBath     0.227122
# LotArea          0.263843
# HalfBath         0.284108
# OpenPorchSF      0.315856
# 2ndFlrSF         0.319334
# WoodDeckSF       0.324413
# LotFrontage      0.351799
# BsmtFinSF1       0.386420
# Fireplaces       0.466929
# MasVnrArea       0.477493
# GarageYrBlt      0.486362
# YearRemodAdd     0.507101
# YearBuilt        0.522897
# TotRmsAbvGrd     0.533723
# FullBath         0.560664
# 1stFlrSF         0.605852
# TotalBsmtSF      0.613581
# GarageArea       0.623431
# GarageCars       0.640409
# ...

# %%
df_train.isnull() #df_train의 것 중, 값이 널인 경우 값이 T 반환
# Out:
#          Id  MSSubClass  MSZoning  ...  SaleType  SaleCondition  SalePrice
# 0     False       False     False  ...     False          False      False
# 1     False       False     False  ...     False          False      False
# 2     False       False     False  ...     False          False      False
# 3     False       False     False  ...     False          False      False
# 4     False       False     False  ...     False          False      False
# ...     ...         ...       ...  ...       ...            ...        ...
# 1455  False       False     False  ...     False          False      False
# 1456  False       False     False  ...     False          False      False
# 1457  False       False     False  ...     False          False      False
# 1458  False       False     False  ...     False          False      False
# 1459  False       False     False  ...     False          False      False
#
# [1460 rows x 81 columns]

# %%
#이걸 SUMMATIon하면
df_missing = df_train.isnull().sum()
df_missing #칼럼별 None값을 다 더해줌
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df_missing = df_missing.sort_values(ascending = False)
df_missing[:50] #PoolQC의 경우, 1453에 해당하는 값이 null임.
#총 1453개의 집은 수영장이 없어서, 해당 요소가 널이다
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageCond         81
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageQual         81
# BsmtExposure       38
# BsmtFinType2       38
# BsmtFinType1       37
# BsmtCond           37
# BsmtQual           37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# Utilities           0
# YearRemodAdd        0
# MSSubClass          0
# Foundation          0
# ExterCond           0
# ExterQual           0
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
# RoofStyle           0
# YearBuilt           0
# LotConfig           0
# OverallCond         0
# OverallQual         0
# HouseStyle          0
# BldgType            0
# Condition2          0
# BsmtFinSF1          0
# MSZoning            0
# LotArea             0
# Street              0
# Condition1          0
# ...

# %%
"""
미싱데이터가 하나라도 있는 row는 제거를 하거나
그 칼럼은 제외를 하는 등의 방식을 쓸 수 있다
미싱이 난 줄을 삭제하는 방식을 취하게 되면,
PoolQc의 경우 거의 다 널인데, 이를 제거하면 남는 게 지극히 없음

따라서, alley 피쳐가 널이므로 앨리만 없애는 방법을 쓰는 게 낫다
비정상값 널이 있다면 그 널이 요소를 전부 데이터셋에서 날려보자

혹은 -값이나 임으의 값을 넣어 feature을 살리려는 방식도 있을 것이다
해당 요소가 상관관계가 높을 수도 있으니, 수기로 데이터 고정작업도 필요할 수 이씀
"""
df_missing[df_missing > 0].plot.bar()

# %%
df_missing = df_missing[df_missing > 0]
df_missing #얘넬 걸러내보자
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageCond        81
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# dtype: int64

# %%
df_missing.index.tolist()
df_train = df_train.drop(df_missing.index.tolist(), axis = 1)
df_train
#axis가 1이므로, 첫 번째 인덱스를 보며 list로 자르겠다
#칼럼에 리스트를 넘겨, 열을 보면서 자르겠다
#만일 [0,1,2], axis=1이라면, 0, 1, 2의 3개 row가 날라가게 될 것
#['Id', MSSubClass], axis=1이라면 아이디와 서브클래스의 2개가 날라갈 것
# Out:
#         Id  MSSubClass MSZoning  ...  SaleType SaleCondition SalePrice
# 0        1          60       RL  ...        WD        Normal    208500
# 1        2          20       RL  ...        WD        Normal    181500
# 2        3          60       RL  ...        WD        Normal    223500
# 3        4          70       RL  ...        WD       Abnorml    140000
# 4        5          60       RL  ...        WD        Normal    250000
# ...    ...         ...      ...  ...       ...           ...       ...
# 1455  1456          60       RL  ...        WD        Normal    175000
# 1456  1457          20       RL  ...        WD        Normal    210000
# 1457  1458          70       RL  ...        WD        Normal    266500
# 1458  1459          20       RL  ...        WD        Normal    142125
# 1459  1460          20       RL  ...        WD        Normal    147500
#
# [1460 rows x 62 columns]

# %%
len(df_train.columns) #널값이 있는 칼럼을 전부 삭제했으므로, train엔 61개의 칼럼만 남음
# Out:
# 62

# %%
df_train.isnull().sum().max() #널값 전부 없어졌는지 확인
# Out:
# 0

# %%
numeric = [f for f in df_train.columns if df_train.dtypes[f] != 'object'] #숫자형
numeric.remove('Id')
numeric.remove('SalePrice')
numeric
# Out:
# ['MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
categorical = [f for f in df_train.columns if df_train.dtypes[f] == 'object'] #숫자형 아닌거
categorical
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'Functional',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
df_train['ExterQual']
# Out:
# 0       Gd
# 1       TA
# 2       Gd
# 3       TA
# 4       Gd
#         ..
# 1455    TA
# 1456    TA
# 1457    Ex
# 1458    TA
# 1459    Gd
# Name: ExterQual, Length: 1460, dtype: object

# %%
#텍스트를 보기 쉽도록 정수형으로 바꿔보자
#카테고리별로 description을 보고 바꾸는 편이 나을 것이다. 그러나 비효율적
#각 그레이드 별 집값의 통계(평균값 등)를 보고 점수를 매길 수 있다
#예를 들어 위의 것을 예로 들면
df_order = pd.DataFrame()
df_order
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
feature_name = 'ExterQual'
df_train[feature_name]
# Out:
# 0       Gd
# 1       TA
# 2       Gd
# 3       TA
# 4       Gd
#         ..
# 1455    TA
# 1456    TA
# 1457    Ex
# 1458    TA
# 1459    Gd
# Name: ExterQual, Length: 1460, dtype: object

# %%
df_order['val'] = df_train[feature_name].unique()
df_order #유니크한 값들만 남김
# Out:
#   val
# 0  Gd
# 1  TA
# 2  Ex
# 3  Fa

# %%
df_order.index = df_order.val
df_order
# Out:
#     val
# val
# Gd   Gd
# TA   TA
# Ex   Ex
# Fa   Fa

# %%
#굿에 해당하는 것만 꼽아 세일프라이스의 평균을 구하려면
#일단 df_train에서 feature_name별로 groupby를 한다
df_train[[feature_name, "SalePrice"]]
# Out:
#      ExterQual  SalePrice
# 0           Gd     208500
# 1           TA     181500
# 2           Gd     223500
# 3           TA     140000
# 4           Gd     250000
# ...        ...        ...
# 1455        TA     175000
# 1456        TA     210000
# 1457        Ex     266500
# 1458        TA     142125
# 1459        Gd     147500
#
# [1460 rows x 2 columns]

# %%
df_order['mean_price'] = df_train[[feature_name, "SalePrice"]].groupby(feature_name).mean()['SalePrice']
df_order = df_order.sort_values('mean_price') #meanprice순으로 sorting
df_order #각 grade별로 속하는 집들의 sale price의 평균값이 나오게 됨
# Out:
#     val     mean_price
# val
# Fa   Fa   87985.214286
# TA   TA  144341.313466
# Gd   Gd  231633.510246
# Ex   Ex  367360.961538

# %%
df_order['rank'] = range(1, len(df_order) + 1)
df_order #텍스트형을 숫자로 바꿔보자. rank라는 것을 만들어, 1로, 길이당 +1해서 넣기
# Out:
#     val     mean_price  rank
# val
# Fa   Fa   87985.214286     1
# TA   TA  144341.313466     2
# Gd   Gd  231633.510246     3
# Ex   Ex  367360.961538     4

# %%
#이제 이 각각을 딕셔너리로 만든다
df_order = df_order['rank'].to_dict()
df_order
# Out:
# {'Ex': 4, 'Fa': 1, 'Gd': 3, 'TA': 2}

# %%
df_train[[feature_name]]
# Out:
#      ExterQual
# 0           Gd
# 1           TA
# 2           Gd
# 3           TA
# 4           Gd
# ...        ...
# 1455        TA
# 1456        TA
# 1457        Ex
# 1458        TA
# 1459        Gd
#
# [1460 rows x 1 columns]

# %%
df_train.head(1)
# Out:
#    Id  MSSubClass MSZoning  LotArea  ... YrSold SaleType SaleCondition SalePrice
# 0   1          60       RL     8450  ...   2008       WD        Normal    208500
#
# [1 rows x 62 columns]

# %%
#df_train의 featurename에 rank를 붙인 칼럼을 하나 만들며,
#람다 x(df_order의 칼럼 하나하나)를 하나 받아, df_order칼럼의 [ExterQual]에 
#해당하는 점수를 rank에 대입함
df_train[feature_name + '_rank'] = df_train.apply(lambda x: df_order[x[feature_name]], axis = 1)
df_train[[feature_name, feature_name+'_rank']] #exterqual_rank에 각각 gd냐 ex냐에 등등에 점수가 대입된 것을 볼 수 있다
# Out:
#      ExterQual  ExterQual_rank
# 0           Gd               3
# 1           TA               2
# 2           Gd               3
# 3           TA               2
# 4           Gd               3
# ...        ...             ...
# 1455        TA               2
# 1456        TA               2
# 1457        Ex               4
# 1458        TA               2
# 1459        Gd               3
#
# [1460 rows x 2 columns]

# %%
# 이를 각 하나하나 다 해야된다.
# 그럴 순 없으니, 함수로 만든다

def add_rank_feature(feature_name, rank_feature_name) :
  df_order = pd.DataFrame()
  df_order['val'] = df_train[feature_name].unique()
  df_order.index = df_order.val

  df_order['mean_price'] = df_train[[feature_name, 'SalePrice']].groupby(feature_name).mean()['SalePrice']
  df_order['rank'] = range(1, len(df_order) + 1)
  df_order = df_order['rank'].to_dict()

  df_train[rank_feature_name] = df_train.apply(lambda x: df_order[x[feature_name]], axis = 1)

# %%
rank_features = []
for feature_name in categorical :
  rank_feature_name = feature_name + '_rank'
  print(feature_name, '-->', rank_feature_name)
  add_rank_feature(feature_name, rank_feature_name)
  rank_features.append(rank_feature_name)
# Out:
# MSZoning --> MSZoning_rank
# Street --> Street_rank
# LotShape --> LotShape_rank
# LandContour --> LandContour_rank
# Utilities --> Utilities_rank
# LotConfig --> LotConfig_rank
# LandSlope --> LandSlope_rank
# Neighborhood --> Neighborhood_rank
# Condition1 --> Condition1_rank
# Condition2 --> Condition2_rank
# BldgType --> BldgType_rank
# HouseStyle --> HouseStyle_rank
# RoofStyle --> RoofStyle_rank
# RoofMatl --> RoofMatl_rank
# Exterior1st --> Exterior1st_rank
# Exterior2nd --> Exterior2nd_rank
# ExterQual --> ExterQual_rank
# ExterCond --> ExterCond_rank
# Foundation --> Foundation_rank
# Heating --> Heating_rank
# HeatingQC --> HeatingQC_rank
# CentralAir --> CentralAir_rank
# KitchenQual --> KitchenQual_rank
# Functional --> Functional_rank
# PavedDrive --> PavedDrive_rank
# SaleType --> SaleType_rank
# SaleCondition --> SaleCondition_rank

# %%
df_train #칼럼이 굉장히 많이 증가함을 알 수있다. 숫자형으로 변경됨. 머신러닝에 넣을 데이터가 마련됨
# Out:
#         Id  MSSubClass  ... SaleType_rank  SaleCondition_rank
# 0        1          60  ...             1                   1
# 1        2          20  ...             1                   1
# 2        3          60  ...             1                   1
# 3        4          70  ...             1                   2
# 4        5          60  ...             1                   1
# ...    ...         ...  ...           ...                 ...
# 1455  1456          60  ...             1                   1
# 1456  1457          20  ...             1                   1
# 1457  1458          70  ...             1                   1
# 1458  1459          20  ...             1                   1
# 1459  1460          20  ...             1                   1
#
# [1460 rows x 89 columns]

# %%
rank_features
# Out:
# ['MSZoning_rank',
#  'Street_rank',
#  'LotShape_rank',
#  'LandContour_rank',
#  'Utilities_rank',
#  'LotConfig_rank',
#  'LandSlope_rank',
#  'Neighborhood_rank',
#  'Condition1_rank',
#  'Condition2_rank',
#  'BldgType_rank',
#  'HouseStyle_rank',
#  'RoofStyle_rank',
#  'RoofMatl_rank',
#  'Exterior1st_rank',
#  'Exterior2nd_rank',
#  'ExterQual_rank',
#  'ExterCond_rank',
#  'Foundation_rank',
#  'Heating_rank',
#  'HeatingQC_rank',
#  'CentralAir_rank',
#  'KitchenQual_rank',
#  'Functional_rank',
#  'PavedDrive_rank',
#  'SaleType_rank',
#  'SaleCondition_rank']

# %%
df_processed = df_train[rank_features + numeric]
df_processed #전처리한 것들만 남김
# Out:
#       MSZoning_rank  Street_rank  LotShape_rank  ...  MiscVal  MoSold  YrSold
# 0                 1            1              1  ...        0       2    2008
# 1                 1            1              1  ...        0       5    2007
# 2                 1            1              2  ...        0       9    2008
# 3                 1            1              2  ...        0       2    2006
# 4                 1            1              2  ...        0      12    2008
# ...             ...          ...            ...  ...      ...     ...     ...
# 1455              1            1              1  ...        0       8    2007
# 1456              1            1              1  ...        0       2    2010
# 1457              1            1              1  ...     2500       5    2010
# 1458              1            1              1  ...        0       4    2010
# 1459              1            1              1  ...        0       6    2008
#
# [1460 rows x 60 columns]

# %%
df_processed['SalePrice'] = df_train['SalePrice']
df_processed
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       MSZoning_rank  Street_rank  LotShape_rank  ...  MoSold  YrSold  SalePrice
# 0                 1            1              1  ...       2    2008     208500
# 1                 1            1              1  ...       5    2007     181500
# 2                 1            1              2  ...       9    2008     223500
# 3                 1            1              2  ...       2    2006     140000
# 4                 1            1              2  ...      12    2008     250000
# ...             ...          ...            ...  ...     ...     ...        ...
# ...

# %%
#다시한면 correlation matrix 생성
cormat = df_processed.corr()
f, ax = plt.subplots(figsize=(12,9))
sns.heatmap(cormat, vmax=.8, square=True);

# %%
df_features = cormat.sort_values(by=['SalePrice'])['SalePrice']
df_features[-40:]
# Out:
# YrSold               -0.028923
# LowQualFinSF         -0.025606
# MiscVal              -0.021190
# BsmtHalfBath         -0.016844
# Utilities_rank       -0.014314
# BsmtFinSF2           -0.011378
# Condition2_rank      -0.004833
# RoofMatl_rank         0.035820
# 3SsnPorch             0.044584
# MoSold                0.046432
# LandSlope_rank        0.051152
# SaleType_rank         0.072896
# LandContour_rank      0.092009
# PoolArea              0.092404
# LotConfig_rank        0.109106
# ScreenPorch           0.111447
# SaleCondition_rank    0.142503
# RoofStyle_rank        0.159332
# BedroomAbvGr          0.168213
# BsmtUnfSF             0.214479
# BsmtFullBath          0.227122
# LotArea               0.263843
# LotShape_rank         0.267759
# HalfBath              0.284108
# OpenPorchSF           0.315856
# 2ndFlrSF              0.319334
# WoodDeckSF            0.324413
# BsmtFinSF1            0.386420
# Fireplaces            0.466929
# YearRemodAdd          0.507101
# ...

# %%
from sklearn.model_selection import train_test_split
df_features[-16:-1].index.tolist()
# Out:
# ['OpenPorchSF',
#  '2ndFlrSF',
#  'WoodDeckSF',
#  'BsmtFinSF1',
#  'Fireplaces',
#  'YearRemodAdd',
#  'YearBuilt',
#  'TotRmsAbvGrd',
#  'FullBath',
#  '1stFlrSF',
#  'TotalBsmtSF',
#  'GarageArea',
#  'GarageCars',
#  'GrLivArea',
#  'OverallQual']

# %%
df_processed
# Out:
#       MSZoning_rank  Street_rank  LotShape_rank  ...  MoSold  YrSold  SalePrice
# 0                 1            1              1  ...       2    2008     208500
# 1                 1            1              1  ...       5    2007     181500
# 2                 1            1              2  ...       9    2008     223500
# 3                 1            1              2  ...       2    2006     140000
# 4                 1            1              2  ...      12    2008     250000
# ...             ...          ...            ...  ...     ...     ...        ...
# 1455              1            1              1  ...       8    2007     175000
# 1456              1            1              1  ...       2    2010     210000
# 1457              1            1              1  ...       5    2010     266500
# 1458              1            1              1  ...       4    2010     142125
# 1459              1            1              1  ...       6    2008     147500
#
# ...

# %%
X = df_processed[df_features[-16:-1].index.tolist()]
y = df_processed['SalePrice']
X.shape, y.shape
# Out:
# ((1460, 15), (1460,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train.shape, y_train.shape #(1314, 15) * (15,1) + bias = (1314,1)
# Out:
# ((1314, 15), (1314,))

# %%
y_train.shape, y_test.shape
# Out:
# ((1314,), (146,))

# %%
from sklearn.linear_model import Lasso
model = Lasso()
model = model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 809534762218.5767, tolerance: 787334624.1028306
#   positive)

# %%
pred = model.predict(X_test)
plt.scatter(y_test, pred) #실제정답 y_test와 predict의 상관관계

# %%
from sklearn import metrics

def print_evaluate(true, predicted) :
  mae = metrics.mean_absolute_error(true, predicted)
  mse = metrics.mean_squared_error(true, predicted)
  rmse = np.sqrt(metrics.mean_squared_error(true, predicted))
  r2_square = metrics.r2_score(true, predicted)

  print('MAE: ', mae)
  print('MSE: ', mse)
  print('RMSE: ', rmse)
  print('R2 Sqaure: ', r2_square)

# %%
print_evaluate(y_test, pred) #정답값과 예측값 넣어 평가
# Out:
# MAE:  23794.14269597338
# MSE:  1754358902.586029
# RMSE:  41885.06777583186
# R2 Sqaure:  0.80798642166732

# %%
df_results = pd.concat([y_test.reset_index(), pd.DataFrame(pred)], axis = 1)
df_results
# Out:
#      index  SalePrice              0
# 0      892     154500  155918.012756
# 1     1105     325000  308343.211554
# 2      413     115000  109925.280172
# 3      522     159000  176015.061794
# 4     1036     315500  299781.721455
# ..     ...        ...            ...
# 141    526     132000  119118.906907
# 142    101     178000  185965.751837
# 143   1092     136500  183903.421321
# 144    411     145000  140071.706967
# 145   1392     123000  127179.567816
#
# [146 rows x 3 columns]

# %%
import scipy.stats as st
plt.figure(2); plt.title('Normal')
sns.distplot(df_processed['SalePrice'], kde = False, fit = st.norm)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(3); plt.title('Log Normal')
sns.distplot(df_processed['SalePrice'], kde = False, fit = st.lognorm)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(3); plt.title('Normal')
sns.distplot(np.log(df_processed['SalePrice']), kde=False, fit=st.norm)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
model = Lasso()
model = model.fit(X_train, np.log(y_train))

pred = np.exp(model.predict(X_test))
print_evaluate(y_test, pred) #MAE가 감소한 것을 볼 수 있음
# Out:
# MAE:  21617.328358371098
# MSE:  1345501205.1928196
# RMSE:  36681.07420990857
# R2 Sqaure:  0.8527356627659387
